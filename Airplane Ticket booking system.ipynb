# %%
global f
f = 0


# this t_air function is used to select airplane class
def t_air():
    global f
    f = f + 1
    print("Which Class do you prefer")
    print("1,Economic Class")
    print("2,Business Class ")
    print("3,First Class")
    print("4,back")
    air = int(input("choose your class: "))
    if air == 4:
        # in this it goes to center function and from center it goes to air function and it comes back here and then go to seating
        center()
        seating()
        return 0
    if f == 1:
        seating()


# this seating  function used to select seat
def seating():
    print("which type of sitting do you prefer ")
    print("1,Window seating")
    print("2,Middle seating")
    print("3,aisle seating")
    a = int(input("choose your seat: "))
    ticket = int(input("number of ticket do you want?: "))
    timing(a)


# this timing function used to select timing
def timing(a):
    time1 = {
        "1": "10.00",
        "2": "1.10",
        "3": "4.20",
        "4": "7.30"
    }
    time2 = {
        "1": "10.15",
        "2": "1.25",
        "3": "4.35",
        "4": "7.45"
    }
    time3 = {
        "1": "10.30",
        "2": "1.40",
        "3": "4.50",
        "4": "8.00"
    }
    if a == 1:
        print("choose your time:")
        print(time1)
        t = input("select your time:")
        x = time1[t]
        print("successful!, happy journey and your booked at " + x)
    elif a == 2:
        print("choose your time:")
        print(time2)
        t = input("select your time:")
        x = time2[t]
        print("successful!, happy journey and your booked at " + x)
    elif a == 3:
        print("choose your time:")
        print(time3)
        t = input("select your time:")
        x = time3[t]
        print("successful!, happy journey and your booked at  " + x)
    return 0


def air(seating):
    if seating == 1:
        t_air()
    elif seating == 2:
        t_air()
    elif seating == 3:
        t_air()
    elif seating == 4:
        city()
    else:
        print("wrong choice")


def center():
    print("which airlines do you want to travel? ")
    print("1,Emirades")
    print("2,Etihad")
    print("3,Qatar")
    print("4,back")
    a = int(input("choose your option: "))
    air(a)
    return 0


# this function is used to select city
def city():
    print("Hi welcome to airline ticket booking: ")
    print("where you want to travel?:")
    print("1,Paris 1")
    print("2,London 2 ")
    print("3,Tokyo 3 ")
    place = int(input("choose your option: "))
    if place == 1:
        center()
    elif place == 2:
        center()
    elif place == 3:
        center()
    else:
        print("wrong choice")


city()  # it calls the function city
